# %% [markdown]
# # This chapter will cover:
# - Loading a simple delimited data file
# - Counting how many rows and columns were loaded
# - Determining which type of data was loaded
# - Looking at different parts of the data by subsetting rows and columns

# %%
#Importing pandas  and aliasing it as pd
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# # 1 Loading a simple delimited data file

# %%
gap=pd.read_csv("data/gapminder.tsv", sep="\t") # read_csv funtion allows us to read the dataset into pandas
#Sep paramater is providered with \t because this a tsv file

# %%
#Let check the type
type(gap)
# Out:
# pandas.core.frame.DataFrame

# %%
#Get the number of rows and columns

# %%
gap.shape
# Out:
# (1704, 6)

# %%
# 1704=rows and 6=columns

# %%
#Get columns names 
gap.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
#Get the dtypes of all columns

# %%
gap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# # 1.3 Looking at Columns, Rows, and Cells

# %%
#Subsetting Columns by Name

# %%
country_df=gap['country']

# %%
country_df.head() # show the first 5 observations
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
# show the last 5 observations
country_df.tail()
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
# Looking at country, continent, and year
subset=gap[['country', 'continent', 'year']]
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %% [markdown]
# # 1.3.2 Subsetting Rows by loc

# %% [markdown]
# # We can use the loc attribute on the dataframe to subset rows based on the
#  #index label.

# %%
gap.loc[0] #first row by label
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
gap.loc[99] # get the 100th label byindex
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap       721.186
# Name: 99, dtype: object

# %%
#we can use the tail method to return the last 1 row,
#instead of the default 5

gap.tail(n=1)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# Subsetting Multiple Rows

# %%
gap.loc[[1,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 1    Afghanistan      Asia  1957   30.332   9240934   820.853030
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %% [markdown]
# # Subset Rows by Row Number: iloc

# %%
gap.iloc[[1,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 1    Afghanistan      Asia  1957   30.332   9240934   820.853030
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
gap.iloc[-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
pd.__version__
# Out:
# '0.24.2'

# %% [markdown]
# # 1.3.2.3 Subsetting Rows With ix No Longer Works in Pandas v0.20

# %% [markdown]
# # Subsetting columns

# %%
# subset columns with loc
# note the position of the colon
# it is used to select all rows
subset=gap.loc[:, ['year','country']]

# %%
subset.head()
# Out:
#    year      country
# 0  1952  Afghanistan
# 1  1957  Afghanistan
# 2  1962  Afghanistan
# 3  1967  Afghanistan
# 4  1972  Afghanistan

# %%
# subset columns with iloc
# iloc will alow us to use integers
# -1 will select the last column
sub2=gap.iloc[:,[2,4,-1]]

# %%
sub2.head()
# Out:
#    year       pop   gdpPercap
# 0  1952   8425333  779.445314
# 1  1957   9240934  820.853030
# 2  1962  10267083  853.100710
# 3  1967  11537966  836.197138
# 4  1972  13079460  739.981106

# %% [markdown]
# #  Subsetting Columns by Range

# %%
# create a range of integers from 0 to 4 inclusive
small_range=list(range(0,5))
small_range
# Out:
# [0, 1, 2, 3, 4]

# %%
sub3=gap.iloc[:, small_range]
sub3.head()
# Out:
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460

# %% [markdown]
# # 1.3.3.3 Slicing Columns

# %%
# slice the first 3 columns
sub_slice=gap.iloc[:, :3]
sub_slice.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
# slice columns 3 to 5 inclusive
slice_gap=gap.iloc[:, 3:6]
slice_gap.head()
# Out:
#    lifeExp       pop   gdpPercap
# 0   28.801   8425333  779.445314
# 1   30.332   9240934  820.853030
# 2   31.997  10267083  853.100710
# 3   34.020  11537966  836.197138
# 4   36.088  13079460  739.981106

# %%
gap.iloc[:, 0:6:].head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gap.iloc[:, 0::2].head()
# Out:
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460

# %% [markdown]
# # 1.3.3.5 Subsetting Multiple Rows and Columns

# %%
# get the 1st, 100th, and 1000th rows
# from the 1st, 4th, and 6th columns
# the columns we are hoping to get are
# country, lifeExp, and gdpPercap
sub_multiple=gap.iloc[[1,99,999],[0, 3, 5]]
sub_multiple.head()
# Out:
#          country  lifeExp    gdpPercap
# 1    Afghanistan   30.332   820.853030
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
gap.loc[[1,99,999], ['country', 'lifeExp', 'gdpPercap']].head()
# Out:
#          country  lifeExp    gdpPercap
# 1    Afghanistan   30.332   820.853030
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %% [markdown]
# # 1.4 Grouped and Aggregated Calculations
# There are several initial questions that we can ask ourselves:
#    1. For each year in our data, what was the average life expectancy? What
#      is the average life expectancy, population, and GDP?
#    2. What if we stratify the data by continent and perform the same
#           calculations?
#    3. How many countries are listed in each continent?

# %%
gap.head(n=10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
# For each year in our data, what was the average life expectancy?
each_year_life=gap.groupby('year')['lifeExp'].mean()
each_year_life.reset_index()
# Out:
#     year    lifeExp
# 0   1952  49.057620
# 1   1957  51.507401
# 2   1962  53.609249
# 3   1967  55.678290
# 4   1972  57.647386
# 5   1977  59.570157
# 6   1982  61.533197
# 7   1987  63.212613
# 8   1992  64.160338
# 9   1997  65.014676
# 10  2002  65.694923
# 11  2007  67.007423

# %%
# What is the average life expectancy, population, and GDP?
avg=gap.groupby('year')['lifeExp','pop', 'gdpPercap'].mean()
avg.reset_index()
# Out:
#     year    lifeExp           pop     gdpPercap
# 0   1952  49.057620  1.695040e+07   3725.276046
# 1   1957  51.507401  1.876341e+07   4299.408345
# 2   1962  53.609249  2.042101e+07   4725.812342
# 3   1967  55.678290  2.265830e+07   5483.653047
# 4   1972  57.647386  2.518998e+07   6770.082815
# 5   1977  59.570157  2.767638e+07   7313.166421
# 6   1982  61.533197  3.020730e+07   7518.901673
# 7   1987  63.212613  3.303857e+07   7900.920218
# 8   1992  64.160338  3.599092e+07   8158.608521
# 9   1997  65.014676  3.883947e+07   9090.175363
# 10  2002  65.694923  4.145759e+07   9917.848365
# 11  2007  67.007423  4.402122e+07  11680.071820

# %%
# What if we stratify the data by continent and perform the same
# calculations?

# %%
year_strat=gap.groupby(['year', 'continent'])['lifeExp', 'gdpPercap'].mean()
year_strat.reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %%
# use the nunique (number unique)
# to calculate the number of unique values in a series
continent=gap.groupby('continent')['country'].nunique()
continent
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
# use the nunique (number unique)
# to calculate the number of unique values in a series
continent=gap.groupby('continent')['country'].value_counts()
continent
# Out:
# continent  country
# Africa     Algeria                     12
#            Angola                      12
#            Benin                       12
#            Botswana                    12
#            Burkina Faso                12
#            Burundi                     12
#            Cameroon                    12
#            Central African Republic    12
#            Chad                        12
#            Comoros                     12
#            Congo, Dem. Rep.            12
#            Congo, Rep.                 12
#            Cote d'Ivoire               12
#            Djibouti                    12
#            Egypt                       12
#            Equatorial Guinea           12
#            Eritrea                     12
#            Ethiopia                    12
#            Gabon                       12
#            Gambia                      12
#            Ghana                       12
#            Guinea                      12
# ...

# %% [markdown]
# # Basic Plots

# %%
global_yearly_life_expectancy =gap.groupby('year')['lifeExp'].mean()

# %%
global_yearly_life_expectancy.plot()
